# %% [markdown]
# <a href="https://colab.research.google.com/github/sesmael/ECGR-4105/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import time
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize images to the range [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the CNN model
def create_cnn():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        MaxPooling2D((2, 2)),
        Dropout(0.2),

        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Dropout(0.3),

        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Dropout(0.4),

        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Create the model
cnn_model = create_cnn()

# Train the model and record training time
start_time = time.time()

history = cnn_model.fit(x_train, y_train, epochs=200, batch_size=64, validation_data=(x_test, y_test))

end_time = time.time()
training_time = end_time - start_time

# Evaluate the model on the test set
loss, accuracy = cnn_model.evaluate(x_test, y_test)

# Display the results
print(f"Training Time: {training_time:.2f} seconds")
print(f"Test Accuracy: {accuracy * 100:.2f}%")
print(f"Test Loss: {loss:.4f}")

# Plot training/validation loss and accuracy
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs. Epochs')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epochs')
plt.legend()
plt.show()

# Save the model (optional)
cnn_model.save('cnn_cifar10_model.h5')
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.2273 - loss: 2.0380 - val_accuracy: 0.4643 - val_loss: 1.4746
# Epoch 2/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4586 - loss: 1.4869 - val_accuracy: 0.5497 - val_loss: 1.2564
# Epoch 3/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5183 - loss: 1.3477 - val_accuracy: 0.5848 - val_loss: 1.1802
# Epoch 4/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.5501 - loss: 1.2644 - val_accuracy: 0.6199 - val_loss: 1.0659
# Epoch 5/200
# ...

# %%
def create_extended_cnn_fixed():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3), padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.2),

        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.3),

        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.4),

        # New Convolutional Layer with 'same' padding
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        Dropout(0.5),

        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Create and train the model
extended_cnn_model = create_extended_cnn_fixed()

# Train and evaluate as before
start_time_extended = time.time()
history_extended = extended_cnn_model.fit(x_train, y_train, epochs=200, batch_size=64, validation_data=(x_test, y_test))
end_time_extended = time.time()
training_time_extended = end_time_extended - start_time_extended

loss_extended, accuracy_extended = extended_cnn_model.evaluate(x_test, y_test)
print(f"Extended Model Training Time: {training_time_extended:.2f} seconds")
print(f"Extended Model Test Accuracy: {accuracy_extended * 100:.2f}%")
print(f"Extended Model Test Loss: {loss_extended:.4f}")
# Out:
# Epoch 1/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.2413 - loss: 1.9983 - val_accuracy: 0.5065 - val_loss: 1.3572
# Epoch 2/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4822 - loss: 1.4051 - val_accuracy: 0.5896 - val_loss: 1.1420
# Epoch 3/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5528 - loss: 1.2492 - val_accuracy: 0.6275 - val_loss: 1.0626
# Epoch 4/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5824 - loss: 1.1673 - val_accuracy: 0.6416 - val_loss: 1.0218
# Epoch 5/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.6120 - loss: 1.0983 - val_accuracy: 0.6728 - val_loss: 0.9486
# Epoch 6/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.6306 - loss: 1.0466 - val_accuracy: 0.6884 - val_loss: 0.8961
# Epoch 7/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6392 - loss: 1.0253 - val_accuracy: 0.6504 - val_loss: 0.9880
# Epoch 8/200
# ...

# %%
plt.figure()
plt.plot(history_extended.history['loss'], label='Training Loss')
plt.plot(history_extended.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs. Epochs')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_extended.history['accuracy'], label='Training Accuracy')
plt.plot(history_extended.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epochs')
plt.legend()
plt.show()

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import time

# Define a single ResNet block
def resnet_block(inputs, filters, kernel_size=3, stride=1):
    # Shortcut connection
    shortcut = inputs

    # First convolutional layer
    x = Conv2D(filters, kernel_size, strides=stride, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    # Second convolutional layer
    x = Conv2D(filters, kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    # Add shortcut to the output of the second conv layer
    x = Add()([x, shortcut])
    x = ReLU()(x)

    return x
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense

def build_resnet10(input_shape=(32, 32, 3), num_classes=10):
    inputs = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (3, 3), strides=1, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    # Stack 10 ResNet blocks
    for _ in range(10):
        x = resnet_block(x, 64)

    # Global average pooling and classification layer
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    # Create the model
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model
# Load and preprocess CIFAR-10 data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize the images to [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build the ResNet-10 model
resnet10_model = build_resnet10()

# Train the model and record training time
import time
start_time = time.time()

history_resnet10 = resnet10_model.fit(x_train, y_train, epochs=200, batch_size=64, validation_data=(x_test, y_test))

end_time = time.time()
training_time = end_time - start_time

# Evaluate the ResNet-10 model
loss, accuracy = resnet10_model.evaluate(x_test, y_test)

# Print results
print(f"ResNet-10 Training Time: {training_time:.2f} seconds")
print(f"ResNet-10 Test Accuracy: {accuracy * 100:.2f}%")
print(f"ResNet-10 Test Loss: {loss:.4f}")

# Plot training/validation metrics
plt.figure()
plt.plot(history_resnet10.history['loss'], label='Training Loss')
plt.plot(history_resnet10.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('ResNet-10 Loss vs. Epochs')
plt.legend()
plt.show()

plt.figure()
plt.plot(history_resnet10.history['accuracy'], label='Training Accuracy')
plt.plot(history_resnet10.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('ResNet-10 Accuracy vs. Epochs')
plt.legend()
plt.show()

# Save the model (optional)
resnet10_model.save('resnet10_cifar10_model.h5')
# Out:
# Epoch 1/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 101s 101ms/step - accuracy: 0.4276 - loss: 1.6210 - val_accuracy: 0.5012 - val_loss: 1.4776
# Epoch 2/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 121s 87ms/step - accuracy: 0.6470 - loss: 0.9801 - val_accuracy: 0.3451 - val_loss: 2.8790
# Epoch 3/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.7159 - loss: 0.8086 - val_accuracy: 0.4868 - val_loss: 2.1465
# Epoch 4/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 88ms/step - accuracy: 0.7610 - loss: 0.6886 - val_accuracy: 0.7054 - val_loss: 0.8451
# Epoch 5/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 80s 86ms/step - accuracy: 0.7939 - loss: 0.5866 - val_accuracy: 0.5865 - val_loss: 1.2916
# Epoch 6/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 86ms/step - accuracy: 0.8207 - loss: 0.5193 - val_accuracy: 0.6318 - val_loss: 1.2564
# Epoch 7/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 86ms/step - accuracy: 0.8379 - loss: 0.4664 - val_accuracy: 0.7069 - val_loss: 0.9254
# Epoch 8/200
# ...
